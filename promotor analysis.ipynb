# %%
bur = '...'
can = '...'
col = '...'
ct = '...'
edi = '...'
hi = '...'
kn = '...'
ler = '...'
mt = '...'
no = '...'
oy ='...'
po = '...'
rsch = '...'
sf = '...'
tsu = '...'
wil = '...'
ws = '...'
wu = '...'
zu = '...'

# %%
promotors1={
'bur' : '...',
'can' : '...',
'col' : '...',
'ct' : '...',
'edi' : '...',
'hi' : '...',
'kn' : '...',
'ler' : '...',
'mt' : '...',
'no' : '...',
'oy' :'...',
'po' : '...',
'rsch' : '...',
'sf' : '...',
'tsu' : '...',
'wil' : '...',
'ws' : '...',
'wu' : '...',
'zu' : '...',
}

# %%
bindsites = ['actcat', 'actttg', 'tgataa', 'agatag', 'agatag', 'tgccgactt', 'tgtctc', 'ccattg', 'aacaaac', 'caaca', 'ccagtg', 'accaaac', 'ttgacc', 'ttgact', 'tgtctc', 'aaccaaac', 'aactaac']
# Out:
# 17

# %%
for i in bindsites:
    if i in bur:
        print ('yes')
    else:
        print ('no')
# Out:
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes

# %%
for key, value in promotors1.iteritems():
    for i in bindsites:
        if i in value:
            pass
        else:
            print (key+': '+ i)
# Out:
# no: tgccgactt
# ler: tgccgactt
# can: tgccgactt
# ct: tgccgactt
